# %% [markdown]
# # 📦 YOLOv8 Custom Training (Google Colab)
# Use this notebook to train a model to detect ONLY cardboard boxes.
#
# ### Steps:
# 1.  **Runtime** -> **Change runtime type** -> **T4 GPU**.
# 2.  Run the cells below one by one.

# %%
# 1. Install YOLOv8
# %pip install ultralytics
import ultralytics
ultralytics.checks()

# %%
# 2. Download Dataset (Roboflow)
# PASTE YOUR ROBOFLOW CODE HERE
# (Go to Roboflow > Dataset > Export > YOLOv8 > Copy Code and paste it below)
# It should look like: !pip install roboflow && ...

# %%
# 3. Train Model
# We train for 50 epochs on image size 640.
# 'data.yaml' is automatically creating by the dataset download step.

# !yolo detect train data=data.yaml model=yolov8n.pt epochs=50 imgsz=640 name=yolov8n_custom_box

# %%
# 4. Download Weights
from google.colab import files
files.download('/content/runs/detect/yolov8n_custom_box/weights/best.pt')
